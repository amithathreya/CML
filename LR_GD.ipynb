# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# extract the data
data = pd.read_csv("Linear Regression - Sheet1.csv")
data.keys()
# Out:
# Index(['X', 'Y'], dtype='object')

# %%
data.head(10)
# Out:
#     X         Y
# 0   1  3.888889
# 1   2  4.555556
# 2   3  5.222222
# 3   4  5.888889
# 4   5  6.555556
# 5   6  7.222222
# 6   7  7.888889
# 7   8  8.555556
# 8   9  9.222222
# 9  10  9.888889

# %%
#split the Data

X = data["X"]
Y = data["Y"]

# %%
def split_data(train_ratio = 0.75 , test_ratio = 0.25):
  cols = np.array(X)
  rows = np.array(Y)
  train_size = int(len(data)*train_ratio)
  test_size = int(len(data)*test_ratio)

  X_train = cols[:train_size]
  X_test = cols[train_size:]
  Y_train = rows[:train_size]
  Y_test = rows[train_size:]

  return X_train, X_test, Y_train, Y_test

# %%
# Hyperparameters
learning_rate = 0.001
iterations = 1000

# Initialize parameters
m = 0
c = 0

# Gradient Descent
n = float(len(X))
X_train, X_test, Y_train, Y_test = split_data()

for i in range(iterations):
    Y_pred = m * X_train + c
    Dm = (-2/n) * sum(X_train * (Y_train - Y_pred))
    Dc = (-2/n) * sum(Y_train - Y_pred)
    m = m - learning_rate * Dm
    c = c - learning_rate * Dc

# Make predictions
Y_pred = m * X_test + c

plt.scatter(X_train, Y_train, color='red', marker='+', linewidth=1)
Y_pred = m * X_train + b
plt.plot(X_train, Y_pred, color='green')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression using Gradient Descent')
plt.show()
# Out:
# <ipython-input-73-75b0b1f7deec>:17: RuntimeWarning: overflow encountered in scalar add
#   Dm = (-2/n) * sum(X_train * (Y_train - Y_pred))
# <ipython-input-73-75b0b1f7deec>:19: RuntimeWarning: invalid value encountered in scalar subtract
#   m = m - learning_rate * Dm
